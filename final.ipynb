# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv('sales_asp_footwear.csv')
location_master = pd.read_csv('location master.csv')

# %%
timedimension  = pd.read_csv('TimeDimension final.csv')
df4 = pd.read_csv('united arab emirates.csv')

# %%
loccol = 'Location.[Location]'
history ='Total Sales Units'
country = 'Location.[Location Country]'
time = 'Time.[WeekKey]'

# %%
sales = sales.merge(location_master[[loccol,country]],on=loccol,how='left')
sales = sales.merge(timedimension[['Time.[WeekKey]', 'Time.[Week]']].drop_duplicates(),on='Time.[Week]',how='left')
sales.head()
# Out:
#   Format.[Format] Version.[Version Name]    Time.[Week]  \
# 0             FOL     CurrentWorkingView  Jan WK01 2021
# 1             FOL     CurrentWorkingView  Jan WK01 2021
# 2             FOL     CurrentWorkingView  Jan WK01 2021
# 3             FOL     CurrentWorkingView  Jan WK01 2021
# 4             FOL     CurrentWorkingView  Jan WK01 2021
#
#   Sales Domain.[Channel] Location.[Location]   Item.[Planning Item]  \
# 0              CLEARANCE                1028  ADEF0309|OWNTHEGAME K
# 1              CLEARANCE                1041  ADEF0309|OWNTHEGAME K
# 2              CLEARANCE                1403  ADEF0309|OWNTHEGAME K
# 3              CLEARANCE                1004  ADFW4566|OWNTHEGAME K
# 4              CLEARANCE                1071  ADFW4566|OWNTHEGAME K
#
#   Item.[Division]  Total Sales Units     ASP Location.[Location Country]  \
# 0        FOOTWEAR                  1  227.62              UTD.ARAB EMIR.
# ...

# %%
df = sales.groupby([country,time])[history].sum().reset_index()
df[time] = pd.to_datetime(df[time])

# %%
  # Corrected events_dates dictionary
events_dates = {
    'UTD.ARAB EMIR.': [
        ('Dubai shopping festival', '2021-12-15', '2022-01-27', 'yellow'),
        ('Dubai marathon', '2021-12-10', '2021-12-12', 'orange'),
        ('Black Friday', '2021-11-25', '2021-11-26', 'green'),
        ('Dubai international jazz festival', '2022-02-19', '2022-02-27', 'pink'),
        ('Ramadan', '2021-04-14', '2021-05-12', 'red'),
        ('Ramadan', '2022-04-3', '2022-05-2', 'red'),
        ('EID -AL-ADHA', '2021-07-21', '2021-07-24', 'purple'),
        ('EID -AL-ADHA', '2022-07-10', '2022-07-14', 'purple'),
    ],

    'SAUDI ARABIA': [
        ('Haya Jeddah shopping festival', '2021-01-26', '2021-01-27', 'violet'),
        ('Unification of the kingdom day', '2021-09-23', '2021-09-24', 'black'),
        ('Riyadh spring festival', '2021-03-07', '2021-03-08', 'purple'),
        ('Ramadan', '2021-04-14', '2021-05-12', 'red'),
        ('Ramadan', '2022-04-3', '2022-05-2', 'red'),
        ('EID -AL-ADHA', '2021-07-21', '2021-07-24', 'purple'),
        ('EID -AL-ADHA', '2022-07-10', '2022-07-14', 'purple'),
    ],

    'QATAR': [
        ('Qatar international art festival', '2022-01-24', '2022-02-04', 'grey'),
        ('European jazz festival', '2022-11-09', '2022-11-11', 'white'),
        ('Fifa world cup 2022', '2022-11-20', '2022-12-18', 'brown'),
        ('Ramadan', '2021-04-14', '2021-05-12', 'red'),
        ('Ramadan', '2022-04-3', '2022-05-2', 'red'),
        ('EID -AL-ADHA', '2021-07-21', '2021-07-24', 'purple'),
        ('EID -AL-ADHA', '2022-07-10', '2022-07-14', 'purple'),
    ],

    'OMAN': [
        ('USA-dubai/trade exhibition', '2021-12-11', '2021-12-12', 'yellow'),
        ('Salalah Tourism Festival in Salalah', '2021-07-15', '2021-08-20', 'orange'),
        ('Ramadan', '2021-04-14', '2021-05-12', 'red'),
        ('The Muscat Festival', '2023-01-19', '2023-02-04', 'pink'),
        ('Ramadan', '2022-04-3', '2022-05-2', 'red'),
        ('EID -AL-ADHA', '2021-07-21', '2021-07-24', 'purple'),
        ('EID -AL-ADHA', '2022-07-10', '2022-07-14', 'purple'),
    ],

    'KUWAIT': [
        ('Prophet Birthday', '2021-10-20', '2021-10-21', 'orange'),
        ('Prophet Birthday', '2022-10-07', '2022-10-08', 'orange'),
        ('Ramadan', '2021-04-14', '2021-05-12', 'red'),
        ('Ramadan', '2022-04-3', '2022-05-2', 'red'),
        ('EID -AL-ADHA', '2021-07-21', '2021-07-24', 'purple'),
        ('EID -AL-ADHA', '2022-07-10', '2022-07-14', 'purple'),
    ],

    'EGYPT': [
        ('Coptic Orthodox Christmas', '2021-01-07', '2021-01-08', 'green'),
        ('Ramadan', '2021-04-14', '2021-05-12', 'red'),
        ('Ramadan', '2022-04-3', '2022-05-2', 'red'),
        ('EID -AL-ADHA', '2021-07-21', '2021-07-24', 'purple'),
        ('EID -AL-ADHA', '2022-07-10', '2022-07-14', 'purple'),
    ],

    'BAHRAIN': [
        ('Prophet Birthday', '2021-10-20', '2021-10-21', 'orange'),
        ('Prophet Birthday', '2022-10-07', '2022-10-08', 'orange'),
        ('Ramadan', '2021-04-14', '2021-05-12', 'red'),
        ('Ramadan', '2022-04-3', '2022-05-2', 'red'),
        ('EID -AL-ADHA', '2021-07-21', '2021-07-24', 'purple'),
        ('EID -AL-ADHA', '2022-07-10', '2022-07-14', 'purple'),
    ],
}

# %%
for name,grp in df.groupby(country):
    #plt.figure(figsize=(16,10),dpi=200)
    grp.plot(x=time,y=history,figsize=(16,10))
    #plt.plot(grp[time],grp[history], marker='o', linestyle='-')
    plt.title('Country plot of :{}'.format(name))
    country_data = grp.copy()
   
  # Annotate the plot with events for the specific country
# Plot the country's sales history on the primary y-axis
#plt.plot(country_data[time], country_data[history], marker='o', linestyle='-', label='Sales History')
    if name in events_dates:
        for event, start_date, end_date, color in events_dates[name]:
            start_date = pd.to_datetime(start_date)
            end_date = pd.to_datetime(end_date) if end_date else pd.to_datetime(start_date)
            plt.axvspan(start_date, end_date, color=color, alpha=0.2, label=event)

            event_data = country_data[country_data[time] == start_date]
            # Use the index of the event_data as x values for markers and the sales history value as y values
            #plt.scatter(event_data.index, event_data[history], marker='o', color='red', label=event)

plt.title('Country plot of: {}'.format(name))
plt.xlabel('Week')
plt.ylabel('Total Sales Units')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
